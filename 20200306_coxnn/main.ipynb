# %%
from process import PHOTOMICS
import pandas as pd
from keras.optimizers import SGD,Adam,RMSprop
import tensorflow as tf
from numpy.random import seed
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model

import nnet_survival
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
ALGO = 'tsne'
OMICS = 'meth'
PH = 'non-PH'
obj = PHOTOMICS(OMICS, PH=False, clinical=False)

# %%
clinical = pd.read_csv('data/clinical_data_subsets/clinical_data.csv')
dataset_mrna, dataset_meth, dataset_mirna, training_list = obj.input_process1(ALGO+'_training_data_mrna', ALGO+'_training_data_meth', ALGO+'_training_data_mirna')
print(len(dataset_meth),'|', len(dataset_mirna),'|', len(dataset_mrna))
t, f, sample, age, breaks, n_intervals, y_train_array, indices, rand_range = obj.input_process2(training_list, clinical)
clinical_feat, train_id_clinical = obj.process3(clinical, training_list)
# Out:
# Data processing-I...
# 100 images to array
# 200 images to array
# 300 images to array
# 400 images to array
#   0%|          | 2/458 [00:00<00:25, 17.54it/s]All meth images done!
# 458 | 458 | 458
# Data processing-II...
# 100%|██████████| 458/458 [00:24<00:00, 18.66it/s]
# 100%|██████████| 458/458 [00:00<00:00, 1196134.02it/s]Done!
#
# Processing clinical features
# Features Processed

# %%
len(dataset_mrna), len(dataset_meth), len(dataset_mirna), len(clinical_feat)
# Out:
# (458, 458, 458, 458)

# %%
results = pd.DataFrame({'Conc': [], 'Brier': [], 'p_value': [], 'ConcVal': [], 'BrierVal': [], 'PVAlueVal': [], 'ConcBm': [], 'BrierBm': [], 'p_valueBm': [], 'ConcValBm': [], 'BrierValBm': [], 'PVAlueVal_Bm': []})

for random in range(20):
    seed(123)
    tf.random.set_random_seed(123)

    #Parameters for model
    indices = range(len(f))
    #random=3
    split_ratio = 0.2
    batch_size = 8
    sgd  = SGD(lr=0.0001, decay=1e-6, momentum=0.9, nesterov=True)
    early_stopping = EarlyStopping(monitor='val_loss', patience=30)
    filepath='checkpoints/'+PH+'/'+ALGO+'_'+OMICS+'/two_dense_weights-improvement-' + str(random) + '.hdf5'
    model_checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

    #Initilize and compile model
    obj.start_sess()
    cox=obj.architecture(n_intervals)
    #cox.summary()
    cox.compile(loss=nnet_survival.surv_likelihood(n_intervals), optimizer=sgd)

    #Test-train split
    X_train_mrna, X_test_mrna, y_train, y_test, ind_train_1, ind_test_1 = train_test_split(dataset_mrna, y_train_array,indices, test_size=split_ratio, random_state=random)
    X_train_meth, X_test_meth, y_train, y_test, ind_train_2, ind_test_2 = train_test_split(dataset_meth, y_train_array,indices, test_size=split_ratio, random_state=random)
    X_train_mirna, X_test_mirna, y_train, y_test, ind_train_2, ind_test_2 = train_test_split(dataset_mirna, y_train_array,indices, test_size=split_ratio, random_state=random)
    clinical_train, clinical_test, placeholder_train, placeholder_test, ind_train, ind_test = train_test_split(clinical_feat, y_train_array, indices, test_size=split_ratio, random_state=random)
    T_train, T_test, F_train, F_test, TF_ind_train, TF_ind_test = train_test_split(t, f,indices, test_size=split_ratio, random_state=random)

    train_omics_data = [X_train_meth]
    test_omics_data = [X_test_meth]

    history=cox.fit(train_omics_data, y_train, batch_size=batch_size, epochs=500, verbose=1, validation_data=(test_omics_data,y_test), callbacks=[early_stopping,model_checkpoint])

    #Load saved best model
    if PH=="PH":
        cox_bm = load_model('checkpoints/'+PH+'/'+ALGO+'_'+OMICS+'/two_dense_weights-improvement-'+str(random)+'.hdf5', custom_objects={'PropHazards': nnet_survival.PropHazards(n_intervals), 'loss': nnet_survival.surv_likelihood(n_intervals)})
    elif PH=="non-PH":
        cox_bm = load_model('checkpoints/'+PH+'/'+ALGO+'_'+OMICS+'/two_dense_weights-improvement-'+str(random)+'.hdf5', custom_objects={'loss': nnet_survival.surv_likelihood(n_intervals)})


    #Generate training and testing results for last saved and best model
    y_pred, y_pred_val = obj.train_val_results(cox, train_omics_data, test_omics_data,batch_size)
    y_pred_bm, y_pred_val_bm = obj.train_val_results(cox_bm, train_omics_data, test_omics_data,batch_size)

    #Calculate surv prob and medians for last saved and best model
    #Function surv_prob takes three arguments [training prediction(pred_y), validation prediction (y_pred_val), time(t) in years ]
    one_year_survival_prob, one_year_survival_prob_val, one_yr_median, one_yr_median_val = obj.surv_prob(y_pred, y_pred_val,breaks, 1)
    five_year_survival_prob, five_year_survival_prob_val, five_yr_median, five_yr_median_val = obj.surv_prob(y_pred, y_pred_val, breaks, 5)

    one_year_survival_prob_bm, one_year_survival_prob_val_bm, one_yr_median_bm, one_yr_median_val_bm = obj.surv_prob(y_pred_bm, y_pred_val_bm, breaks, 1)
    five_year_survival_prob_bm, five_year_survival_prob_val_bm, five_yr_median_bm, five_yr_median_val_bm = obj.surv_prob(y_pred_bm, y_pred_val_bm, breaks, 5)

    #Calculate concordance index and brier scores for last saved and best model
    five_yr_train_concordance, five_yr_train_brier, five_yr_p_value = obj.metrices(T_train, five_year_survival_prob, F_train, y_train, 5, 'train', five_yr_median, breaks)
    five_yr_val_concordance, five_yr_val_brier, five_yr_p_value_val = obj.metrices(T_test, five_year_survival_prob_val, F_test, y_test, 5, 'test', five_yr_median_val, breaks)
    five_yr_train_concordance_bm, five_yr_train_brier_bm, five_yr_p_value_bm = obj.metrices(T_train, five_year_survival_prob_bm, F_train, y_train, 5, 'train', five_yr_median_bm, breaks)
    five_yr_val_concordance_bm, five_yr_val_brier_bm, five_yr_p_value_val_bm = obj.metrices(T_test, five_year_survival_prob_val_bm, F_test, y_test, 5, 'test', five_yr_median_val_bm, breaks)

    five_yr_ipcw = obj.ipcw(F_train, F_test, T_train, T_test, five_year_survival_prob_val)
    five_yr_ipcw_bm = obj.ipcw(F_train, F_test, T_train, T_test, five_year_survival_prob_val_bm)

    df = {'Conc': five_yr_train_concordance,'Brier':five_yr_train_brier,'p_value':five_yr_p_value, 'ConcVal': five_yr_val_concordance,'BrierVal':five_yr_val_brier, 'PVAlueVal':five_yr_p_value_val, 'ipcw':five_yr_ipcw, 'ConcBm': five_yr_train_concordance_bm,'BrierBm':five_yr_train_brier_bm,'p_valueBm':five_yr_p_value_bm, 'ConcValBm': five_yr_val_concordance_bm,'BrierValBm':five_yr_val_brier_bm, 'PVAlueVal_Bm':five_yr_p_value_val_bm, 'ipcwBm':five_yr_ipcw_bm}

    results = results.append(df, ignore_index=True)
    results.to_csv(ALGO+'_models/'+PH+'/'+OMICS+'/res_' + str(random) + '.csv')
    obj.reset_keras()
results.to_csv(ALGO+'_models/'+PH+'/'+OMICS+'/res_total.csv')
# Out:
# 97 - val_loss: 1.5499
#
# Epoch 00025: val_loss did not improve from 1.40633
# Epoch 26/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.8847 - val_loss: 1.4158
#
# Epoch 00026: val_loss did not improve from 1.40633
# Epoch 27/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.8217 - val_loss: 1.4750
#
# Epoch 00027: val_loss did not improve from 1.40633
# Epoch 28/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.9314 - val_loss: 1.4808
#
# Epoch 00028: val_loss did not improve from 1.40633
# Epoch 29/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.9207 - val_loss: 1.4461
#
# Epoch 00029: val_loss did not improve from 1.40633
# Epoch 30/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.6915 - val_loss: 1.4489
#
# Epoch 00030: val_loss did not improve from 1.40633
# Epoch 31/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.7524 - val_loss: 1.5006
#
# Epoch 00031: val_loss did not improve from 1.40633
# Epoch 32/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.6349 - val_loss: 1.5517
#
# Epoch 00032: val_loss did not improve from 1.40633
# Epoch 33/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.8243 - val_loss: 1.4377
#
# Epoch 00033: val_loss did not improve from 1.40633
# Epoch 34/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.7139 - val_loss: 1.4527
#
# Epoch 00034: val_loss did not improve from 1.40633
# Epoch 35/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.8715 - val_loss: 1.4438
#
# Epoch 00035: val_loss did not improve from 1.40633
# Epoch 36/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.6496 - val_loss: 1.5783
#
# Epoch 00036: val_loss did not improve from 1.40633
# Epoch 37/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.7528 - val_loss: 1.4440
#
# Epoch 00037: val_loss did not improve from 1.40633
# Epoch 38/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.8125 - val_loss: 1.4483
#
# Epoch 00038: val_loss did not improve from 1.40633
# Epoch 39/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.7821 - val_loss: 1.4746
#
# Epoch 00039: val_loss did not improve from 1.40633
# Epoch 40/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.7492 - val_loss: 1.4473
#
# Epoch 00040: val_loss did not improve from 1.40633
# Epoch 41/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.8245 - val_loss: 1.5996
#
# Epoch 00041: val_loss did not improve from 1.40633
# Epoch 42/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.7073 - val_loss: 1.5433
#
# Epoch 00042: val_loss did not improve from 1.40633
# Epoch 43/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.6179 - val_loss: 1.5764
#
# Epoch 00043: val_loss did not improve from 1.40633
# Epoch 44/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.6068 - val_loss: 1.5112
#
# Epoch 00044: val_loss did not improve from 1.40633
# Epoch 45/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.8248 - val_loss: 1.5757
#
# Epoch 00045: val_loss did not improve from 1.40633
# Epoch 46/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.7617 - val_loss: 1.4981
#
# Epoch 00046: val_loss did not improve from 1.40633
# Epoch 47/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.7029 - val_loss: 1.5698
#
# Epoch 00047: val_loss did not improve from 1.40633
# Epoch 48/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.6719 - val_loss: 1.4369
#
# Epoch 00048: val_loss did not improve from 1.40633
# Epoch 49/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.6053 - val_loss: 1.5447
#
# Epoch 00049: val_loss did not improve from 1.40633
# Epoch 50/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.6617 - val_loss: 1.4674
#
# Epoch 00050: val_loss did not improve from 1.40633
# Epoch 51/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.6036 - val_loss: 1.4530
#
# Epoch 00051: val_loss did not improve from 1.40633
# Epoch 52/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.6563 - val_loss: 1.5444
#
# Epoch 00052: val_loss did not improve from 1.40633
# 5 year train concordance index for meth: 0.8419234650314368
# 5 year train brier score for meth: 0.10220998354223912
# P-value: 9.176010623957727e-29
# 5 year test concordance index for meth: 0.6179275270184361
# 5 year test brier score for meth: 0.09795829084228311
# P-value: 0.04264490536511778
# 5 year train concordance index for meth: 0.7349608010556548
# 5 year train brier score for meth: 0.22772626230327264
# P-value: 5.90799373981721e-10
# 5 year test concordance index for meth: 0.6096630642085188
# 5 year test brier score for meth: 0.23751261095108256
# P-value: 0.34544534972462493
# Restarting Keras Session...
# Done!
# Exception ignored in: <bound method BaseSession._Callable.__del__ of <tensorflow.python.client.session.BaseSession._Callable object at 0x7f219c3f3208>>
# Traceback (most recent call last):
#   File "/home/dell15/KING/Work_ubuntu/Projects/MO-int/king_env/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1473, in __del__
#     self._session._session, self._handle)
# tensorflow.python.framework.errors_impl.CancelledError: (None, None, 'Session has been closed.')
# Train on 366 samples, validate on 92 samples
# Epoch 1/500
# 366/366 [==============================] - 3s 8ms/step - loss: 6.9048 - val_loss: 3.5226
#
# Epoch 00001: val_loss improved from inf to 3.52259, saving model to checkpoints/non-PH/tsne_meth/two_dense_weights-improvement-18.hdf5
# Epoch 2/500
# 366/366 [==============================] - 3s 8ms/step - loss: 2.6991 - val_loss: 1.9464
#
# Epoch 00002: val_loss improved from 3.52259 to 1.94640, saving model to checkpoints/non-PH/tsne_meth/two_dense_weights-improvement-18.hdf5
# Epoch 3/500
# 366/366 [==============================] - 3s 8ms/step - loss: 2.2486 - val_loss: 1.7799
#
# Epoch 00003: val_loss improved from 1.94640 to 1.77988, saving model to checkpoints/non-PH/tsne_meth/two_dense_weights-improvement-18.hdf5
# Epoch 4/500
# 366/366 [==============================] - 3s 8ms/step - loss: 2.1458 - val_loss: 1.7465
#
# Epoch 00004: val_loss improved from 1.77988 to 1.74654, saving model to checkpoints/non-PH/tsne_meth/two_dense_weights-improvement-18.hdf5
# Epoch 5/500
# 366/366 [==============================] - 3s 8ms/step - loss: 2.0911 - val_loss: 1.6933
#
# Epoch 00005: val_loss improved from 1.74654 to 1.69333, saving model to checkpoints/non-PH/tsne_meth/two_dense_weights-improvement-18.hdf5
# Epoch 6/500
# 366/366 [==============================] - 3s 8ms/step - loss: 2.0393 - val_loss: 1.6026
#
# Epoch 00006: val_loss improved from 1.69333 to 1.60260, saving model to checkpoints/non-PH/tsne_meth/two_dense_weights-improvement-18.hdf5
# Epoch 7/500
# 366/366 [==============================] - 3s 8ms/step - loss: 2.0425 - val_loss: 1.6208
#
# Epoch 00007: val_loss did not improve from 1.60260
# Epoch 8/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.9509 - val_loss: 1.5704
#
# Epoch 00008: val_loss improved from 1.60260 to 1.57041, saving model to checkpoints/non-PH/tsne_meth/two_dense_weights-improvement-18.hdf5
# Epoch 9/500
# 366/366 [==============================] - 3s 8ms/step - loss: 2.0338 - val_loss: 1.8562
#
# Epoch 00009: val_loss did not improve from 1.57041
# Epoch 10/500
# 366/366 [==============================] - 3s 8ms/step - loss: 2.1133 - val_loss: 1.5758
#
# Epoch 00010: val_loss did not improve from 1.57041
# Epoch 11/500
# 366/366 [==============================] - 3s 8ms/step - loss: 2.0657 - val_loss: 1.6220
#
# Epoch 00011: val_loss did not improve from 1.57041
# Epoch 12/500
# 366/366 [==============================] - 3s 8ms/step - loss: 2.1204 - val_loss: 1.7168
#
# Epoch 00012: val_loss did not improve from 1.57041
# Epoch 13/500
# 366/366 [==============================] - 3s 8ms/step - loss: 2.0825 - val_loss: 1.6774
#
# Epoch 00013: val_loss did not improve from 1.57041
# Epoch 14/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.9623 - val_loss: 1.6025
#
# Epoch 00014: val_loss did not improve from 1.57041
# Epoch 15/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.9392 - val_loss: 1.6147
#
# Epoch 00015: val_loss did not improve from 1.57041
# Epoch 16/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.9374 - val_loss: 1.7752
#
# Epoch 00016: val_loss did not improve from 1.57041
# Epoch 17/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.8212 - val_loss: 1.7578
#
# Epoch 00017: val_loss did not improve from 1.57041
# Epoch 18/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.9146 - val_loss: 1.6126
#
# Epoch 00018: val_loss did not improve from 1.57041
# Epoch 19/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.8498 - val_loss: 1.5829
#
# Epoch 00019: val_loss did not improve from 1.57041
# Epoch 20/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.8522 - val_loss: 1.7463
#
# Epoch 00020: val_loss did not improve from 1.57041
# Epoch 21/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.7935 - val_loss: 1.6363
#
# Epoch 00021: val_loss did not improve from 1.57041
# Epoch 22/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.9207 - val_loss: 1.5907
#
# Epoch 00022: val_loss did not improve from 1.57041
# Epoch 23/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.8799 - val_loss: 1.6368
#
# Epoch 00023: val_loss did not improve from 1.57041
# Epoch 24/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.8117 - val_loss: 1.5880
#
# Epoch 00024: val_loss did not improve from 1.57041
# Epoch 25/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.8051 - val_loss: 1.6708
#
# Epoch 00025: val_loss did not improve from 1.57041
# Epoch 26/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.8545 - val_loss: 1.6364
#
# Epoch 00026: val_loss did not improve from 1.57041
# Epoch 27/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.7394 - val_loss: 1.6591
#
# Epoch 00027: val_loss did not improve from 1.57041
# Epoch 28/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.7633 - val_loss: 1.7927
#
# Epoch 00028: val_loss did not improve from 1.57041
# Epoch 29/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.8907 - val_loss: 1.6384
#
# Epoch 00029: val_loss did not improve from 1.57041
# Epoch 30/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.8538 - val_loss: 1.7631
#
# Epoch 00030: val_loss did not improve from 1.57041
# Epoch 31/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.8196 - val_loss: 1.6021
#
# Epoch 00031: val_loss did not improve from 1.57041
# Epoch 32/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.8041 - val_loss: 1.7491
#
# Epoch 00032: val_loss did not improve from 1.57041
# Epoch 33/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.9880 - val_loss: 1.6381
#
# Epoch 00033: val_loss did not improve from 1.57041
# Epoch 34/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.8663 - val_loss: 1.6290
#
# Epoch 00034: val_loss did not improve from 1.57041
# Epoch 35/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.8585 - val_loss: 1.5779
#
# Epoch 00035: val_loss did not improve from 1.57041
# Epoch 36/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.7075 - val_loss: 1.6313
#
# Epoch 00036: val_loss did not improve from 1.57041
# Epoch 37/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.7614 - val_loss: 1.6096
#
# Epoch 00037: val_loss did not improve from 1.57041
# Epoch 38/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.7264 - val_loss: 1.6790
#
# Epoch 00038: val_loss did not improve from 1.57041
# 5 year train concordance index for meth: 0.7651335546072389
# 5 year train brier score for meth: 0.0997675081916772
# P-value: 7.717440449322079e-17
# 5 year test concordance index for meth: 0.6793478260869565
# 5 year test brier score for meth: 0.10140953765635713
# P-value: 0.009343918884004838
# 5 year train concordance index for meth: 0.6655998103366524
# 5 year train brier score for meth: 0.13265019265749298
# P-value: 3.4914447341437375e-07
# 5 year test concordance index for meth: 0.6461352657004831
# 5 year test brier score for meth: 0.12617609991888826
# P-value: 0.09198997721420353
# Restarting Keras Session...
# Done!
# Train on 366 samples, validate on 92 samples
# Epoch 1/500
# 366/366 [==============================] - 3s 8ms/step - loss: 6.2984 - val_loss: 3.7441
#
# Epoch 00001: val_loss improved from inf to 3.74413, saving model to checkpoints/non-PH/tsne_meth/two_dense_weights-improvement-19.hdf5
# Epoch 2/500
# 366/366 [==============================] - 3s 8ms/step - loss: 2.6417 - val_loss: 2.4538
#
# Epoch 00002: val_loss improved from 3.74413 to 2.45375, saving model to checkpoints/non-PH/tsne_meth/two_dense_weights-improvement-19.hdf5
# Epoch 3/500
# 366/366 [==============================] - 3s 8ms/step - loss: 2.4149 - val_loss: 1.8450
#
# Epoch 00003: val_loss improved from 2.45375 to 1.84500, saving model to checkpoints/non-PH/tsne_meth/two_dense_weights-improvement-19.hdf5
# Epoch 4/500
# 366/366 [==============================] - 3s 8ms/step - loss: 2.2477 - val_loss: 1.9115
#
# Epoch 00004: val_loss did not improve from 1.84500
# Epoch 5/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.9319 - val_loss: 1.8060
#
# Epoch 00005: val_loss improved from 1.84500 to 1.80602, saving model to checkpoints/non-PH/tsne_meth/two_dense_weights-improvement-19.hdf5
# Epoch 6/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.9170 - val_loss: 1.7381
#
# Epoch 00006: val_loss improved from 1.80602 to 1.73810, saving model to checkpoints/non-PH/tsne_meth/two_dense_weights-improvement-19.hdf5
# Epoch 7/500
# 366/366 [==============================] - 3s 8ms/step - loss: 2.1148 - val_loss: 1.6919
#
# Epoch 00007: val_loss improved from 1.73810 to 1.69189, saving model to checkpoints/non-PH/tsne_meth/two_dense_weights-improvement-19.hdf5
# Epoch 8/500
# 366/366 [==============================] - 3s 8ms/step - loss: 2.1044 - val_loss: 1.8387
#
# Epoch 00008: val_loss did not improve from 1.69189
# Epoch 9/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.9575 - val_loss: 1.6979
#
# Epoch 00009: val_loss did not improve from 1.69189
# Epoch 10/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.9916 - val_loss: 1.7824
#
# Epoch 00010: val_loss did not improve from 1.69189
# Epoch 11/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.9435 - val_loss: 1.6642
#
# Epoch 00011: val_loss improved from 1.69189 to 1.66421, saving model to checkpoints/non-PH/tsne_meth/two_dense_weights-improvement-19.hdf5
# Epoch 12/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.8843 - val_loss: 1.6744
#
# Epoch 00012: val_loss did not improve from 1.66421
# Epoch 13/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.9724 - val_loss: 1.7907
#
# Epoch 00013: val_loss did not improve from 1.66421
# Epoch 14/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.9868 - val_loss: 1.7077
#
# Epoch 00014: val_loss did not improve from 1.66421
# Epoch 15/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.8599 - val_loss: 1.7537
#
# Epoch 00015: val_loss did not improve from 1.66421
# Epoch 16/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.8721 - val_loss: 1.7319
#
# Epoch 00016: val_loss did not improve from 1.66421
# Epoch 17/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.9074 - val_loss: 1.7233
#
# Epoch 00017: val_loss did not improve from 1.66421
# Epoch 18/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.8684 - val_loss: 1.7318
#
# Epoch 00018: val_loss did not improve from 1.66421
# Epoch 19/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.9393 - val_loss: 1.7457
#
# Epoch 00019: val_loss did not improve from 1.66421
# Epoch 20/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.7860 - val_loss: 1.7278
#
# Epoch 00020: val_loss did not improve from 1.66421
# Epoch 21/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.7709 - val_loss: 1.7967
#
# Epoch 00021: val_loss did not improve from 1.66421
# Epoch 22/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.7411 - val_loss: 1.7561
#
# Epoch 00022: val_loss did not improve from 1.66421
# Epoch 23/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.7079 - val_loss: 1.8713
#
# Epoch 00023: val_loss did not improve from 1.66421
# Epoch 24/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.6318 - val_loss: 1.7701
#
# Epoch 00024: val_loss did not improve from 1.66421
# Epoch 25/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.7872 - val_loss: 1.7376
#
# Epoch 00025: val_loss did not improve from 1.66421
# Epoch 26/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.8272 - val_loss: 1.8626
#
# Epoch 00026: val_loss did not improve from 1.66421
# Epoch 27/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.8513 - val_loss: 1.8080
#
# Epoch 00027: val_loss did not improve from 1.66421
# Epoch 28/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.7412 - val_loss: 1.7436
#
# Epoch 00028: val_loss did not improve from 1.66421
# Epoch 29/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.8078 - val_loss: 1.7637
#
# Epoch 00029: val_loss did not improve from 1.66421
# Epoch 30/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.9733 - val_loss: 1.9016
#
# Epoch 00030: val_loss did not improve from 1.66421
# Epoch 31/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.9817 - val_loss: 1.6985
#
# Epoch 00031: val_loss did not improve from 1.66421
# Epoch 32/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.8056 - val_loss: 1.8369
#
# Epoch 00032: val_loss did not improve from 1.66421
# Epoch 33/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.8162 - val_loss: 1.6901
#
# Epoch 00033: val_loss did not improve from 1.66421
# Epoch 34/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.7643 - val_loss: 1.6983
#
# Epoch 00034: val_loss did not improve from 1.66421
# Epoch 35/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.8901 - val_loss: 1.6974
#
# Epoch 00035: val_loss did not improve from 1.66421
# Epoch 36/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.6328 - val_loss: 1.7553
#
# Epoch 00036: val_loss did not improve from 1.66421
# Epoch 37/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.6546 - val_loss: 1.6977
#
# Epoch 00037: val_loss did not improve from 1.66421
# Epoch 38/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.6295 - val_loss: 1.7356
#
# Epoch 00038: val_loss did not improve from 1.66421
# Epoch 39/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.9167 - val_loss: 1.6843
#
# Epoch 00039: val_loss did not improve from 1.66421
# Epoch 40/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.7427 - val_loss: 1.8279
#
# Epoch 00040: val_loss did not improve from 1.66421
# Epoch 41/500
# 366/366 [==============================] - 3s 8ms/step - loss: 1.6154 - val_loss: 1.7199
#
# Epoch 00041: val_loss did not improve from 1.66421
# 5 year train concordance index for meth: 0.8264073208414214
# 5 year train brier score for meth: 0.12803501967431083
# P-value: 3.845737998465743e-22
# 5 year test concordance index for meth: 0.4864066193853428
# 5 year test brier score for meth: 0.13961627053589332
# P-value: 0.5220475840255785
# 5 year train concordance index for meth: 0.7373925444677732
# 5 year train brier score for meth: 0.12087395964723842
# P-value: 4.013174033175374e-10
# 5 year test concordance index for meth: 0.48936170212765956
# 5 year test brier score for meth: 0.12583483354144784
# P-value: 0.7184323927920707
# Restarting Keras Session...
# Done!

# %%
struct_train = np.zeros(len(F_train), dtype={'names':('F_train', 'T_train'),'formats':('?','i4')})
struct_test = np.zeros(len(F_test), dtype={'names':('F_test', 'T_test'),'formats':('?','i4')})
struct_train['F_train'] = F_train.astype('bool')
struct_train['T_train'] = T_train
struct_test['F_test'] = F_test.astype('bool')
struct_test['T_test'] = T_test

c_ipcw = '%.5g'%(1-concordance_index_ipcw(struct_train, struct_test, five_year_survival_prob_val)[0])

# %%
cox.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 122, 122, 1)  0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 122, 122, 1)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 120, 120, 256 2560        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 120, 120, 256 2560        input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 120, 120, 256 1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 120, 120, 256 1024        conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 120, 120, 256 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 120, 120, 256 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 60, 60, 256)  0           activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 60, 60, 256)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 58, 58, 256)  590080      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 58, 58, 256)  590080      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 58, 58, 256)  1024        conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 58, 58, 256)  1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 58, 58, 256)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 58, 58, 256)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 29, 29, 256)  0           activation_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 29, 29, 256)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 215296)       0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 215296)       0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 430592)       0           flatten_1[0][0]
#                                                                  flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          220463616   concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          65664       dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 128)          0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 39)           5031        dropout_2[0][0]
# ==================================================================================================
# Total params: 221,723,687
# Trainable params: 221,721,639
# Non-trainable params: 2,048
# __________________________________________________________________________________________________

# %%
    # #One-year
    # one_yr_train_concordance, one_yr_train_brier, one_yr_p_value = obj.metrices(T_train, one_year_survival_prob, F_train, y_train, 1, 'train', one_yr_median)
    # one_yr_val_concordance, one_yr_val_brier, one_yr_p_value_val = obj.metrices(T_test, one_year_survival_prob_val, F_test, y_test, 1, 'test', one_yr_median_val)
    # one_yr_train_concordance_bm, one_yr_train_brier_bm, one_yr_p_value_bm = obj.metrices(T_train, one_year_survival_prob_bm, F_train, y_train, 1, 'train', one_yr_median_bm) 
    # one_yr_val_concordance_bm, one_yr_val_brier_bm, one_yr_p_value_val_bm = obj.metrices(T_test, one_year_survival_prob_val_bm, F_test, y_test, 1, 'test', one_yr_median_val_bm)
    #Five-year
